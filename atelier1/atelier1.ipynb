# %% [markdown]
# # Atelier 1 : Agrégation, formatage, définition du besoin
# Dans ce TP, nous allons explorer plusieurs étapes cruciales pour la préparation de données avant leur utilisation dans un modèle de machine learning. Nous utiliserons des données hospitalières pour illustrer les concepts abordés.
#
# N'oubliez pas d'explorer la documentation pour chaque fonction que vous utilisez et d'approfondir vos connaissances sur chaque méthode !
# > **Ressources utiles** :
# > - [Documentation de Pandas](https://pandas.pydata.org/pandas-docs/stable/index.html)
# > - [Documentation de Scikit-learn](https://scikit-learn.org/stable/documentation.html)
# > - [Documentation de Imbalanced-learn](https://imbalanced-learn.org/stable/index.html)

# %% [markdown]
# #### 📊 Récupération des données
#
# Créez deux DataFrames pandas à partir des fichiers JSON (hospital1.json) et CSV (hospital2.json) mis à disposition. Pour cela, utilisez les fonctions `read_csv` et `read_json` de la bibliothèque pandas.
#
# > **Astuce** : Consultez la [documentation de pandas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) si vous avez des doutes sur les options de `read_csv` et `read_json`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# A compléter
df_h2 = pd.read_csv('hopital2.csv')
df_h1 = pd.read_json('hopital1.json')
# pour afficher: df_h1

# %% [markdown]
# #### 🔗 Concaténation des jeux de données
#
# Essayez de **concaténer** les deux DataFrames pour former un seul ensemble de données. Vous pouvez utiliser la fonction `concat` de Pandas.
#
# ❓ **Question** : Que se passe-t-il ? Quels problèmes pouvez-vous observer ?

# %%
# A compléter
df_combined = pd.concat([df_h1, df_h2])
df_combined
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1.0     89.0           66.0           23.0     94.0  28.1
# 1            0.0    137.0           40.0           35.0    168.0  43.1
# 2            3.0     78.0           50.0           32.0     88.0  31.0
# 3            2.0    197.0           70.0           45.0    543.0  30.5
# 4            1.0    189.0           60.0           23.0    846.0  30.1
# ..           ...      ...            ...            ...      ...   ...
# 230          NaN     99.0            NaN            NaN      NaN   NaN
# 231          NaN    121.0            NaN            NaN      NaN   NaN
# 232          NaN    149.0            NaN            NaN      NaN   NaN
# 233          NaN     84.0            NaN            NaN      NaN   NaN
# 234          NaN     89.0            NaN            NaN      NaN   NaN
#
#      DiabetesPedigreeFunction   Age  Outcome  Weight  ...  PressionSanguine  \
# 0                       0.167  21.0      0.0   94.50  ...               NaN
# 1                       2.288  33.0      1.0  116.48  ...               NaN
# 2                       0.248  26.0      1.0   69.31  ...               NaN
# 3                       0.158  53.0      1.0   77.52  ...               NaN
# 4                       0.398  59.0      1.0   80.64  ...               NaN
# ..                        ...   ...      ...     ...  ...               ...
# 230                       NaN   NaN      NaN     NaN  ...              60.0
# 231                       NaN   NaN      NaN     NaN  ...              66.0
# 232                       NaN   NaN      NaN     NaN  ...              68.0
# 233                       NaN   NaN      NaN     NaN  ...              90.0
# 234                       NaN   NaN      NaN     NaN  ...              76.0
#
#     EpaisseurPeau       Insuline   IMC  FonctionPedigreeDiabete DateNaissance  \
# 0             NaN            NaN   NaN                      NaN           NaN
# 1             NaN            NaN   NaN                      NaN           NaN
# 2             NaN            NaN   NaN                      NaN           NaN
# 3             NaN            NaN   NaN                      NaN           NaN
# 4             NaN            NaN   NaN                      NaN           NaN
# ..            ...            ...   ...                      ...           ...
# 230           1.9   54.0 mu U/ml  26.9                    0.497        1992.0
# 231           3.0  165.0 mu U/ml  34.3                    0.203        1991.0
# 232           2.9  127.0 mu U/ml  29.3                    0.349        1982.0
# 233           2.3   56.0 mu U/ml  39.5                    0.159        1999.0
# 234           3.4   37.0 mu U/ml  31.2                    0.192        2001.0
#
#      Diagnostic  Poids  Taille    Pays
# 0           NaN    NaN     NaN     NaN
# 1           NaN    NaN     NaN     NaN
# 2           NaN    NaN     NaN     NaN
# 3           NaN    NaN     NaN     NaN
# 4           NaN    NaN     NaN     NaN
# ..          ...    ...     ...     ...
# 230         0.0  76.82  168.99  France
# 231         1.0  88.93  161.02     USA
# 232         1.0  76.52  161.60     USA
# 233         0.0  88.93  150.04     USA
# 234         0.0  87.06  167.04     USA
#
# [470 rows x 23 columns]

# %% [markdown]
# #### 🔍 Observation rapide des données
#
# 1. **Entête du DataFrame** 🧾
# Objectif : Affichez les 3 premières lignes du fichier avec `head()` pour une vue d'ensemble rapide.
#
# 2. **Métadonnées** 📊
# Visualisez les **types de données** de chaque colonne en utilisant `info()`.
#
#     ❓ **Question** : Que remarquez-vous concernant les types des colonnes ? Y a-t-il des ajustements à faire ?
#
# 3. **Informations statistiques** 📈
# - Utilisez `value_counts()` sur les colonnes correspondant au nombre de grossesses pour afficher leur distribution.
# - Obtenez un aperçu global des données avec `describe()`.
#
#     ❓ **Question** : Quelles différences faites vous entre les deux jeux de données ?

# %%
# A compléter (1)
df_h2.head(3)
# Out:
#    Grossesses  Glucose  PressionSanguine  EpaisseurPeau      Insuline   IMC  \
# 0           9    134.0              74.0            3.3  60.0 mu U/ml  25.9
# 1           9    120.0              72.0            2.2  56.0 mu U/ml  20.8
# 2           8     74.0              70.0            4.0  49.0 mu U/ml  35.3
#
#    FonctionPedigreeDiabete  DateNaissance  Diagnostic   Poids  Taille   Pays
# 0                    0.460           1943           0   74.01  169.04  India
# 1                    0.733           1976           0   51.96  158.05  India
# 2                    0.705           1985           0  107.17  174.24    USA

# %%
# A compléter (2)
print(df_h1.info())
df_h2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               235 non-null    int64
#  1   Glucose                   235 non-null    int64
#  2   BloodPressure             235 non-null    int64
#  3   SkinThickness             235 non-null    int64
#  4   Insulin                   235 non-null    int64
#  5   BMI                       235 non-null    float64
#  6   DiabetesPedigreeFunction  235 non-null    float64
#  7   Age                       235 non-null    int64
#  8   Outcome                   235 non-null    int64
#  9   Weight                    235 non-null    float64
#  10  Height                    235 non-null    float64
#  11  Country                   235 non-null    object
# dtypes: float64(4), int64(7), object(1)
# memory usage: 22.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Grossesses               235 non-null    int64
#  1   Glucose                  235 non-null    float64
#  2   PressionSanguine         235 non-null    float64
#  3   EpaisseurPeau            235 non-null    float64
#  4   Insuline                 235 non-null    object
#  5   IMC                      235 non-null    float64
#  6   FonctionPedigreeDiabete  235 non-null    float64
#  7   DateNaissance            235 non-null    int64
#  8   Diagnostic               235 non-null    int64
#  9   Poids                    235 non-null    float64
#  10  Taille                   235 non-null    float64
#  11  Pays                     235 non-null    object
# dtypes: float64(7), int64(3), object(2)
# memory usage: 22.2+ KB

# %% [markdown]
# age != date de naissance /
# anglais != français /
# int64 != float64

# %% [markdown]
# On remarque que un des fichier utilise age, l'autre date de naissance.

# %% [markdown]
# L'un l'anglais, l'autre le français.

# %% [markdown]
# On doit changer les types de certaines colonnes, certaines sont en INT, d'autres en FLOAT.

# %%
# A compléter (3)
print(df_h2.value_counts('Grossesses'))
df_h2['Grossesses'].describe()
# Out:
# Grossesses
# 1     54
# 2     42
# 0     39
# 3     25
# 7     16
# 6     13
# 4     11
# 5      9
# 8      8
# 9      7
# 10     4
# 11     4
# 13     2
# 12     1
# Name: count, dtype: int64
# count    235.000000
# mean       3.153191
# std        3.072128
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max       13.000000
# Name: Grossesses, dtype: float64

# %% [markdown]
# value_counts('Grossesses') affiche la fréquence du nombre de grossesses par individu.

# %% [markdown]
# describe() affiche les données statistiques de la colonne sélectionné.

# %% [markdown]
# #### 📊 Visualisation graphique
#
# Affichez la distribution de chaque variable avec un histogramme. Vous pouvez utiliser la méthode ``hist()`` de la classe ``Dataframe``

# %%
# A compléter
df_h2.hist(bins=30, figsize=(15, 10))
plt.show()

# %% [markdown]
# #### 💉 Harmonisation de l'unité de la colonne `Insuline`
#
# **Problème** : Dans le jeu de données JSON, l'insuline est exprimée en texte, avec l'unité précisée (`mu U/ml`). On souhaite avoir une expression an accord avec la colonne Insulin du fichier CSV, c'est à dire sous la forme d'un entier.
#
# **Étapes à suivre** :
# 1. Écrire une fonction pour vérifier que chaque entrée est exprimée en `mu U/ml` (réalisé).
# 2. Écrire une fonction pour **extraire la valeur numérique** de la mesure d'insuline.
# 3. Transformez la colonne pour exprimer la mesure en **valeurs numériques** avec `apply()`.

# %%
def check_insulin_format(insulin_str):
    return isinstance(insulin_str, str) and insulin_str.endswith('mu U/ml')

def extract_insulin_value(insulin_str):
    if check_insulin_format(insulin_str):
        insulin_float = float(str.split(insulin_str, ' ')[0])
        return int(insulin_float)

df_h2['Insuline'] = df_h2['Insuline'].apply(extract_insulin_value)
#df_h2

# %% [markdown]
# #### 📏 Harmonisation des unités de `EpaisseurPeau`
#
# Dans les jeux de données 1 et 2, l'épaisseur de la peau est exprimée avec des unités différentes (en **mm** et en **cm**).
#
# 📝 **Tâche** : Écrivez une fonction qui harmonise les unités pour que toutes les valeurs soient exprimées en **mm**.

# %%
def harmonize_skin_thickness(df):
    # A compléter
    df['EpaisseurPeau'] = df['EpaisseurPeau']*10
    df['EpaisseurPeau'] = df['EpaisseurPeau'].astype(dtype='int64')
    return df

df_h2 = harmonize_skin_thickness(df_h2)
df_h2
# Out:
#      Grossesses  Glucose  PressionSanguine  EpaisseurPeau  Insuline   IMC  \
# 0             9    134.0              74.0             33        60  25.9
# 1             9    120.0              72.0             22        56  20.8
# 2             8     74.0              70.0             40        49  35.3
# 3             0    124.0              56.0             13       105  21.8
# 4             0     74.0              52.0             10        36  27.8
# ..          ...      ...               ...            ...       ...   ...
# 230           6     99.0              60.0             19        54  26.9
# 231           0    121.0              66.0             30       165  34.3
# 232           1    149.0              68.0             29       127  29.3
# 233           4     84.0              90.0             23        56  39.5
# 234           1     89.0              76.0             34        37  31.2
#
#      FonctionPedigreeDiabete  DateNaissance  Diagnostic   Poids  Taille  \
# 0                      0.460           1943           0   74.01  169.04
# 1                      0.733           1976           0   51.96  158.05
# 2                      0.705           1985           0  107.17  174.24
# 3                      0.452           2003           0   76.13  186.87
# 4                      0.269           2002           0   66.17  154.29
# ..                       ...            ...         ...     ...     ...
# 230                    0.497           1992           0   76.82  168.99
# 231                    0.203           1991           1   88.93  161.02
# 232                    0.349           1982           1   76.52  161.60
# 233                    0.159           1999           0   88.93  150.04
# 234                    0.192           2001           0   87.06  167.04
#
#        Pays
# 0     India
# 1     India
# 2       USA
# 3     India
# 4       USA
# ..      ...
# 230  France
# 231     USA
# 232     USA
# 233     USA
# 234     USA
#
# [235 rows x 12 columns]

# %% [markdown]
# #### ⏳ Transformation de la `DateNaissance` en âge
#
# Dans le jeu de données 1, c'est la **date de naissance** qui est exprimée, alors que dans le jeu 2, c'est l'**âge**.
#
# 📝 **Tâche** : Écrivez une fonction qui transforme la colonne `DateNaissance` en une colonne `Age`.

# %%
def date_naissance_to_age(df, current_year=2024):
    df['DateNaissance'] = current_year - df['DateNaissance']

    return df
df_h2 = date_naissance_to_age(df_h2).rename(columns={'DateNaissance': 'Age'})
df_h2
# Out:
#      Grossesses  Glucose  PressionSanguine  EpaisseurPeau  Insuline   IMC  \
# 0             9    134.0              74.0             33        60  25.9
# 1             9    120.0              72.0             22        56  20.8
# 2             8     74.0              70.0             40        49  35.3
# 3             0    124.0              56.0             13       105  21.8
# 4             0     74.0              52.0             10        36  27.8
# ..          ...      ...               ...            ...       ...   ...
# 230           6     99.0              60.0             19        54  26.9
# 231           0    121.0              66.0             30       165  34.3
# 232           1    149.0              68.0             29       127  29.3
# 233           4     84.0              90.0             23        56  39.5
# 234           1     89.0              76.0             34        37  31.2
#
#      FonctionPedigreeDiabete  Age  Diagnostic   Poids  Taille    Pays
# 0                      0.460   81           0   74.01  169.04   India
# 1                      0.733   48           0   51.96  158.05   India
# 2                      0.705   39           0  107.17  174.24     USA
# 3                      0.452   21           0   76.13  186.87   India
# 4                      0.269   22           0   66.17  154.29     USA
# ..                       ...  ...         ...     ...     ...     ...
# 230                    0.497   32           0   76.82  168.99  France
# 231                    0.203   33           1   88.93  161.02     USA
# 232                    0.349   42           1   76.52  161.60     USA
# 233                    0.159   25           0   88.93  150.04     USA
# 234                    0.192   23           0   87.06  167.04     USA
#
# [235 rows x 12 columns]

# %% [markdown]
# #### 🔄 Renommer les colonnes du jeu de données 2
#
# Utilisez la méthode `rename()` de pandas pour aligner les noms des colonnes avec ceux du jeu de données 1.

# %%
# A compléter
df_h2.rename(columns={'Grossesses': 'Pregnancies'
                      , 'Glucose': 'Glucose'
                      , 'PressionSanguine': 'BloodPressure'
                      , 'EpaisseurPeau': 'SkinThickness'
                      , 'Insuline': 'Insulin'
                      , 'IMC': 'BMI'
                      , 'FonctionPedigreeDiabete': 'DiabetesPedigreeFunction'
                      , 'Diagnostic': 'Outcome'
                      , 'Poids': 'Weight'
                      , 'Taille': 'Height'
                      , 'Pays': 'Country'}, inplace=True)


df_h2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              9    134.0           74.0             33       60  25.9
# 1              9    120.0           72.0             22       56  20.8
# 2              8     74.0           70.0             40       49  35.3
# 3              0    124.0           56.0             13      105  21.8
# 4              0     74.0           52.0             10       36  27.8
# ..           ...      ...            ...            ...      ...   ...
# 230            6     99.0           60.0             19       54  26.9
# 231            0    121.0           66.0             30      165  34.3
# 232            1    149.0           68.0             29      127  29.3
# 233            4     84.0           90.0             23       56  39.5
# 234            1     89.0           76.0             34       37  31.2
#
#      DiabetesPedigreeFunction  Age  Outcome  Weight  Height Country
# 0                       0.460   81        0   74.01  169.04   India
# 1                       0.733   48        0   51.96  158.05   India
# 2                       0.705   39        0  107.17  174.24     USA
# 3                       0.452   21        0   76.13  186.87   India
# 4                       0.269   22        0   66.17  154.29     USA
# ..                        ...  ...      ...     ...     ...     ...
# 230                     0.497   32        0   76.82  168.99  France
# 231                     0.203   33        1   88.93  161.02     USA
# 232                     0.349   42        1   76.52  161.60     USA
# 233                     0.159   25        0   88.93  150.04     USA
# 234                     0.192   23        0   87.06  167.04     USA
#
# [235 rows x 12 columns]

# %% [markdown]
# #### 📊 Concaténation des jeux de données
#
# Nous allons maintenant fusionner les deux DataFrames que nous avons préparés afin de créer un jeu de données complet. Utilisez la fonction `concat` de pandas pour combiner les DataFrames en un seul DataFrame.

# %%
# A compléter
df_combined2 = pd.concat([df_h1, df_h2])
df_combined2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              1     89.0           66.0             23       94  28.1
# 1              0    137.0           40.0             35      168  43.1
# 2              3     78.0           50.0             32       88  31.0
# 3              2    197.0           70.0             45      543  30.5
# 4              1    189.0           60.0             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 230            6     99.0           60.0             19       54  26.9
# 231            0    121.0           66.0             30      165  34.3
# 232            1    149.0           68.0             29      127  29.3
# 233            4     84.0           90.0             23       56  39.5
# 234            1     89.0           76.0             34       37  31.2
#
#      DiabetesPedigreeFunction  Age  Outcome  Weight  Height Country
# 0                       0.167   21        0   94.50  183.38   India
# 1                       2.288   33        1  116.48  164.39   India
# 2                       0.248   26        1   69.31  149.52   India
# 3                       0.158   53        1   77.52  159.43   India
# 4                       0.398   59        1   80.64  163.68     USA
# ..                        ...  ...      ...     ...     ...     ...
# 230                     0.497   32        0   76.82  168.99  France
# 231                     0.203   33        1   88.93  161.02     USA
# 232                     0.349   42        1   76.52  161.60     USA
# 233                     0.159   25        0   88.93  150.04     USA
# 234                     0.192   23        0   87.06  167.04     USA
#
# [470 rows x 12 columns]

# %% [markdown]
# #### 🔍 Retirer les doublons
#
# La fusion de plusieurs jeux de données peut générer des doublons, qui pourraient fausser l'analyse si on les laisse tels quels. Utilisez la méthode `drop_duplicates` pour supprimer les doublons dans `df_combined`.
#
# > **📝 Astuce** : Utilisez la méthode `duplicated` pour identifier les doublons avant de les retirer.

# %%
# A compléter
df_combined2.drop_duplicates(inplace=True)
df_combined2
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              1     89.0           66.0             23       94  28.1
# 1              0    137.0           40.0             35      168  43.1
# 2              3     78.0           50.0             32       88  31.0
# 3              2    197.0           70.0             45      543  30.5
# 4              1    189.0           60.0             23      846  30.1
# ..           ...      ...            ...            ...      ...   ...
# 184            2    110.0           74.0             29      125  32.4
# 191            1     82.0           64.0             13       95  21.2
# 194           10    125.0           70.0             26      115  31.1
# 202            9    124.0           70.0             33      402  35.4
# 226            2    122.0           52.0             43      158  36.2
#
#      DiabetesPedigreeFunction  Age  Outcome  Weight  Height Country
# 0                       0.167   21        0   94.50  183.38   India
# 1                       2.288   33        1  116.48  164.39   India
# 2                       0.248   26        1   69.31  149.52   India
# 3                       0.158   53        1   77.52  159.43   India
# 4                       0.398   59        1   80.64  163.68     USA
# ..                        ...  ...      ...     ...     ...     ...
# 184                     0.698   27        0  101.14  176.68     USA
# 191                     0.415   23        0   63.40  172.93     USA
# 194                     0.205   41        1   89.78  169.91   India
# 202                     0.282   34        0   93.71  162.70  France
# 226                     0.816   28        0   80.18  148.83   India
#
# [399 rows x 12 columns]

# %% [markdown]
# #### ⚙️ Vérifier la cohérence des données
#
# Nous allons vérifier la cohérence de la colonne BMI (Body Mass Index) pour s'assurer que les données sont en ligne avec les données de poids et de taille. Créez une fonction pour comparer l'IMC calculé à partir de la taille et du poids avec la valeur existante dans `df_combined2`.
#
# > **📌 Rappel** : L'IMC est calculé par la formule suivante : `Poids (kg) / Taille (m)²`.

# %%
import numpy as np


def check_bmi_consistency(df):
    calculated_bmi = df['Weight'] / (df['Height'] / 100) ** 2 # calcul du BMI (je mets la taille en m)
    consistency = np.isclose(calculated_bmi, df['BMI'], atol=0.1) #compare avec une tolérance de 0.1
    return pd.Series(consistency, name="BMI_Consistent") # retourne une Series de booléens (True si le BMI est cohérent, False sinon)


check_bmi_consistency(df_combined2).value_counts()
# Out:
# BMI_Consistent
# True    399
# Name: count, dtype: int64

# %% [markdown]
# #### 🗃️ Choix des colonnes à conserver
#
# Il est parfois nécessaire de réduire le nombre de colonnes pour simplifier l'analyse. Supprimez les colonnes `Height` et `Weight`, car nous avons déjà l'information de l'IMC.
#
# > **🎯 À retenir** : Réduire le nombre de colonnes permet de rendre les analyses plus lisibles et de diminuer la redondance.

# %% [markdown]
# comme l'imc calculé correspond bien à l'imc du tableau, on peut enlever la taille et le poids du tableau.

# %%
df_combined2 = df_combined2.drop(columns=['Height', 'Weight'])
df_combined2.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1     89.0           66.0             23       94  28.1
# 1            0    137.0           40.0             35      168  43.1
# 2            3     78.0           50.0             32       88  31.0
#
#    DiabetesPedigreeFunction  Age  Outcome Country
# 0                     0.167   21        0   India
# 1                     2.288   33        1   India
# 2                     0.248   26        1   India

# %% [markdown]
# #### 🎯 Filtrer les patients de plus de 50 ans pour répondre à la question métier
#
# Nous souhaitons maintenant nous concentrer sur les patients âgés de plus de 50 ans pour une analyse spécifique. Utilisez un filtre pour ne conserver que les lignes où l'âge est supérieur à 50.
#
# > **📝 Astuce** : Utilisez une condition de type `df['Age'] > 50` pour créer le filtre.
#
# Vous pouvez maintenant sauvegarder votre nouveau fichier formatté, au format csv. Pour cela, utilisez la méthode `to_csv`.

# %%
# A compléter
df_over_50 = df_combined2[df_combined2['Age'] > 50]
df_over_50.to_csv("df_over_50.csv", index=False)
df_over_50.head(3)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3            2    197.0           70.0             45      543  30.5
# 4            1    189.0           60.0             23      846  30.1
# 5            5    166.0           72.0             19      175  25.8
#
#    DiabetesPedigreeFunction  Age  Outcome Country
# 3                     0.158   53        1   India
# 4                     0.398   59        1     USA
# 5                     0.587   51        1  France

# %% [markdown]
# ### Conclusion
#
# Nous avons complété le pré-traitement des données en réunissant plusieurs sources, en supprimant les doublons et en vérifiant la consistance. La création de filtres nous a permis de cibler les données pertinentes pour coller au problème métier identifié.
